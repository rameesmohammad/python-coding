# %% [markdown]
# <a href="https://colab.research.google.com/github/rameesmohammad/python-coding/blob/main/pythoncoding2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter total number of monkeys:"))
k=int(input("Enter number of banana monkey can eat:"))
j=int(input("Enter number of peanut monkey can eat:"))
m=int(input("Enter total number of banana:"))
p=int(input("Enter total number of peanut:"))
if(k==0 or j==0):
  print("INVALID INPUT")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%k!=0):
    n=n-1
  print("No. of monkeys in tree:",n)
# Out:
# Enter total number of monkeys:20
# Enter number of banana monkey can eat:2
# Enter number of peanut monkey can eat:3
# Enter total number of banana:12
# Enter total number of peanut:12
# No. of monkeys in tree: 10

# %%
print("using temp")
a=int(input("enter the value of a :"))
b=int(input("enter the value of b :"))
temp=a
a=b
b=temp
print("after swapping:")
print("a=",a)
print("b=",b)
# Out:
# using temp
# enter the value of a :5
# enter the value of b :7
# after swapping:
# a= 7
# b= 5

# %%
print("using , ")
a=int(input("enter the value of a :"))
b=int(input("enter the value of b :"))
a,b=b,a
print("after swapping:")
print("a=",a)
print("b=",b)
# Out:
# using ,
# enter the value of a :7
# enter the value of b :9
# after swapping:
# a= 9
# b= 7

# %%
print("using + and -")
a=int(input("enter the value of a :"))
b=int(input("enter the value of b :"))
a=a+b
b=a-b
a=a-b
print("after swapping:")
print("a=",a)
print("b=",b)
# Out:
# using + and -
# enter the value of a :4
# enter the value of b :8
# after swapping:
# a= 8
# b= 4

# %%
print("using ^")
a=int(input("enter the value of a :"))
b=int(input("enter the value of b :"))
a=a^b
b=a^b
a=a^b
print("after swapping:")
print("a=",a)
print("b=",b)
# Out:
# using ^
# enter the value of a :5
# enter the value of b :9
# after swapping:
# a= 9
# b= 5

# %%
n=int(input("enter total no:of candies in the jar"))
k=int(input("enter number of minimum candies that must be inside JAR ever."))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# enter total no:of candies in the jar10
# enter number of minimum candies that must be inside JAR ever.5
# Enter amout of candies needed:8
# SOLD= 8
# Remaining= 10
# DO you want to continue(1or0):0

# %%
list=[]
a=int(input("enter the size of the list :"))
for i in range(a):
  b=int(input("enter the elements in the list"))
  list.append(b)
print("list : ",list)
# Out:
# enter the size of the list :5
# enter the elements in the list1
# enter the elements in the list2
# enter the elements in the list3
# enter the elements in the list4
# enter the elements in the list5
# list :  [1, 2, 3, 4, 5]

# %%
n = int(input("Enter the no. of elements: "))
num = []
for i in range(n):
    a = int(input("Enter the element: "))
    num.append(a)
large = num[0]
for i in range(1, n):
    if num[i] > large:
        large = num[i]
print("largest element : ",large)
# Out:
# Enter the no. of elements: 5
# Enter the element: 1
# Enter the element: 2
# Enter the element: 78
# Enter the element: 45
# Enter the element: 23
# largest element :  78

# %%
n = int(input("Enter the no. of elements: "))
num = []
for i in range(n):
    a = int(input("Enter the element: "))
    num.append(a)
small = num[0]
for i in range(1, n):
    if num[i] < small:
        small = num[i]
print("smallest element : ",small)
# Out:
# Enter the no. of elements: 4
# Enter the element: 1
# Enter the element: 34
# Enter the element: 67
# Enter the element: 2
# smallest element :  1

# %%
n=int(input("enter the number of elements : "))
sum=0
for i in range(n):
  a=int(input("Enter the element : "))
  sum=sum+a
print("SUM : ",sum)
# Out:
# enter the number of elements : 3
# Enter the element : 12
# Enter the element : 24
# Enter the element : 48
# SUM :  84

# %%
array=[]
limit=int(input("enter the array limit : "))
for i in range(limit):
  array.append(int(input("enter the array elements : ")))
print("array before reversing : ",array)
array.reverse()
print("array after reversing : ",array)
# Out:
# enter the array limit : 5
# enter the array elements : 1
# enter the array elements : 2
# enter the array elements : 3
# enter the array elements : 4
# enter the array elements : 5
# array before reversing :  [1, 2, 3, 4, 5]
# array after reversing :  [5, 4, 3, 2, 1]

# %%
n=int(input("Enter the size of list : "))
list=[]
for i in range(n):
  a=int(input("Enter the  list elements : "))
  list.append(a)
k=int(input("Enter an element to be searched :"))
if k in list:
    print("element exist in the list")
else:
    print("element not exist!")
# Out:
# Enter the size of list : 4
# Enter the  list elements : 1
# Enter the  list elements : 5
# Enter the  list elements : 6
# Enter the  list elements : 3
# Enter an element to be searched :5
# element exist in the list

# %%
array=[]
n=int(input("enter the array limit : "))
for i in range(n):
    array.append(int(input("enter a number : ")))
num = int(input("Enter the number to be searched for counting : "))
print("Number of occurrences : ", array.count(num))
# Out:
# enter the array limit : 5
# enter a number : 3
# enter a number : 3
# enter a number : 5
# enter a number : 2
# enter a number : 1
# Enter the number to be searched for counting : 3
# Number of occurrences :  2

# %%
n=int(input("Enter the size of list : "))
list=[]
for i in range(n):
  a=int(input("Enter the elements : "))
  list.append(a)
list.sort()
print("Second largest element is : ",list[-2])
# Out:
# Enter the size of list : 5
# Enter the elements : 2
# Enter the elements : 6
# Enter the elements : 1
# Enter the elements : 7
# Enter the elements : 3
# Second largest element is :  6

# %%
array=[]
n=int(input("enter the size of array : "))
for i in range(n) :
  array.append(int(input("enter a number : ")))
print("array elements : ",array)
print("array elements after removing duplicates : ",list(set(array)))
# Out:
# enter the size of array : 5
# enter a number : 1
# enter a number : 2
# enter a number : 3
# enter a number : 3
# enter a number : 5
# array elements :  [1, 2, 3, 3, 5]
# array elements after removing duplicates :  [1, 2, 3, 5]

# %%
a=int(input("Enter the size of the list : "))
list=[]
for i in range(a):
  b=int(input("Enter the  list elements : "))
  list.append(b)
print("Original array : ",list)
list.sort()
print("Sorted array : ",list)
# Out:
# Enter the size of the list : 5
# Enter the  list elements : 3
# Enter the  list elements : 6
# Enter the  list elements : 7
# Enter the  list elements : 1
# Enter the  list elements : 6
# Original array :  [3, 6, 7, 1, 6]
# Sorted array :  [1, 3, 6, 6, 7]

# %%
print("READ AN ARRAY USING MAPPING FUNCTION")
i=map(int,(input("Enter elements:").split()))
print(list(i))
# Out:
# READ AN ARRAY USING MAPPING FUNCTION
# Enter elements:66 89 65
# [66, 89, 65]

# %%
li=[10,20,30,40,60,70]
print(li[:])
print(li[2:])
print(li[:3])
print(li[1:4])
print(li[1:3:2])
print(li[::-1])
# Out:
# [10, 20, 30, 40, 60, 70]
# [30, 40, 60, 70]
# [10, 20, 30]
# [20, 30, 40]
# [20]
# [70, 60, 40, 30, 20, 10]

# %%
r = int(input("Enter number of rats: "))
unit = int(input("Enter amount of food each rat eats: "))
n = int(input("Enter number of houses: "))
arr = list(map(int, input("Enter food in each house: ").split()))
if arr is None:
    print(-1)
else:
    required = r * unit
    total = 0
    houses = 0
    for i in range(n):
        total = total + arr[i]
        houses = houses + 1
        if total >= required:
            break
    if total < required:
        print(0)
    else:
        print("Minimum number of houses:", houses)
# Out:
# Enter number of rats: 7
# Enter amount of food each rat eats: 2
# Enter number of houses: 8
# Enter food in each house: 2 8 3 5 7 4 1 2
# Minimum number of houses: 4

# %%
s = str(input("enter the string : "))
rev = ""
i = len(s) - 1
while i >= 0:
    rev = rev + s[i]
    i = i - 1
print(rev)
# Out:
# enter the string : hello
# olleh

# %%
n = int(input("Enter a number : "))
reverse = 0
while n > 0:
    digit = n % 10
    reverse = reverse * 10 + digit
    n = n // 10
print("Reversed number : ", reverse)
# Out:
# Enter a number : 45677
# Reversed number :  77654

# %%
n = int(input("Enter a number: "))
sum = 0
while n > 0:
    digit = n % 10
    sum = sum + digit
    n = n // 10
print("Sum of digits:", sum)
# Out:
# Enter a number: 123
# Sum of digits: 6

# %%
n = int(input("Enter a number: "))
largest = 0
while n > 0:
    digit = n % 10
    if digit > largest:
        largest = digit
    n = n // 10
print("Largest digit:", largest)
# Out:
# Enter a number: 3910
# Largest digit: 9

# %%
n= input("Enter a number: ")
if n== n[::-1]:
    print(n, "is a Palindrome")
else:
    print(n, "is not a Palindrome")
# Out:
# Enter a number: 1234321
# 1234321 is a Palindrome

# %%
str= input("Enter the string : ")
if str== str[::-1]:
    print(str, "is a Palindrome")
else:
    print(str, "is not a Palindrome")
# Out:
# Enter the string : malayalam
# malayalam is a Palindrome

# %%
str1 = input("Enter first string : ")
str2 = input("Enter second string : ")
if sorted(str1) == sorted(str2):
    print("Anagram")
else:
    print("Not anagram")
# Out:
# Enter first string : listen
# Enter second string : silent
# Anagram

# %%
str = input("Enter a string: ")
count = len(str)
print("Number of characters:", count)
# Out:
# Enter a string: ramees
# Number of characters: 6

# %%
str = input("Enter a string: ")
count = 0
for char in str:
    count += 1
print("Number of characters:", count)
# Out:
# Enter a string: ramees
# Number of characters: 6

# %%
s = input("Enter a string: ")
result = ""
for ch in s:
    if ch not in result:
        result += ch
print(result)
# Out:
# Enter a string: banana
# ban

# %%
s=input("Enter a string: ")
vowels=0
consonants=0
for ch in s.lower():
    if ch in "aeiou":
        vowels+=1
    else:
        consonants+=1
print("Vowels:",vowels)
print("Consonants:",consonants)
# Out:
# Enter a string: ramees
# Vowels: 3
# Consonants: 3

# %%
str=input("Enter a string: ")
result = ""
for i in str:
    if i != " ":
        result = result + i
print("after removing whitespace:", result)
# Out:
# Enter a string: ramees mohammad
# after removing whitespace: rameesmohammad

# %%
n1=int(input("enter a num:"))
n2=int(input("enter a num"))
a=[]
b=[]
for i in range(n1):
    a.append(int(input("enter the elements:")))
for i in range(n2):
    b.append(int(input("enter the elements:")))
c=list(set(a+b))
c.sort()
print(c)
length=len(c)
if length%2==1:
    print(c[length//2])
else:
    print((c[length//2-1]+c[length//2])/2)
# Out:
# enter a num:3
# enter a num4
# enter the elements:6
# enter the elements:2
# enter the elements:7
# enter the elements:2
# enter the elements:8
# enter the elements:2
# enter the elements:5
# [2, 5, 6, 7, 8]
# 6

# %%
n=int(input("Enter number:"))
a=bin(n)
b=a[2:]
b=b.replace('0','y').replace('1','0').replace('y','1')
print("RESULT: ",int(b,2))
# Out:
# Enter number:8
# RESULT:  7

# %%
N = int(input("enter the number"))
V = list(map(int, input(" bunch of values as array").split()))
n = int(input("number of spikes"))
result = []
for x in V:
    result.append(x >> n)
print("Result:",*result)
# Out:
# enter the number8
#  bunch of values as array1
# number of spikes2
# Result: 0
